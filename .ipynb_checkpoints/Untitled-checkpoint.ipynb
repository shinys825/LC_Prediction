# %%
## data 저장하기
data = pd.DataFrame.from_csv('./lc_dataframe(cleaning).csv')
data = data.reset_index()
data.tail()
# Out:
#         loan_amnt  term  int_rate  installment  grade  sub_grade  emp_title  \
# 268131      31050    60     21.99       857.40      6         61          1
# 268132      10800    36      7.89       337.89      1         15          1
# 268133       9000    36      9.17       286.92      2         22          1
# 268134      14400    60     25.99       431.06      6         65          0
# 268135       8000    36     12.59       267.98      3         32          1
#
#         emp_length  home_ownership  annual_inc       ...          dti  \
# 268131          10               1    875000.0       ...         9.66
# 268132           8               1     92400.0       ...        19.62
# 268133           1               1     80000.0       ...         3.97
# 268134          11               5     62000.0       ...        16.88
# 268135           4               4     45000.0       ...        26.21
#
#         delinq_2yrs  inq_last_6mths  open_acc  pub_rec  revol_bal  revol_util  \
# ...

# %%
data = sm.add_constant(data)


model_data = sm.OLS(data['loan_amnt'], data.ix[:,0: 23])
result_data = model_data.fit()
result_data
print(result_data.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              loan_amnt   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 2.409e+29
# Date:                Tue, 28 Feb 2017   Prob (F-statistic):               0.00
# Time:                        10:58:56   Log-Likelihood:             5.0131e+06
# No. Observations:              268136   AIC:                        -1.003e+07
# Df Residuals:                  268113   BIC:                        -1.003e+07
# Df Model:                          22
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const               -2.317e-09    3.9e-11    -59.446      0.000   -2.39e-09   -2.24e-09
# ...

# %%
data.tail()
# Out:
#         const  loan_amnt  term  int_rate  installment  grade  sub_grade  \
# 268131    1.0      31050    60     21.99       857.40      6         61
# 268132    1.0      10800    36      7.89       337.89      1         15
# 268133    1.0       9000    36      9.17       286.92      2         22
# 268134    1.0      14400    60     25.99       431.06      6         65
# 268135    1.0       8000    36     12.59       267.98      3         32
#
#         emp_title  emp_length  home_ownership       ...          dti  \
# 268131          1          10               1       ...         9.66
# 268132          1           8               1       ...        19.62
# 268133          1           1               1       ...         3.97
# 268134          0          11               5       ...        16.88
# 268135          1           4               4       ...        26.21
#
#         delinq_2yrs  inq_last_6mths  open_acc  pub_rec  revol_bal  revol_util  \
# ...

# %%
data['revol_util'].shape
# Out:
# (268136,)
